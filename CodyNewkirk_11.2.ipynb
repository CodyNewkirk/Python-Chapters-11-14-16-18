# %%
# Cody Newkirk
# SDEV220
# Importing the zoo module using an alias and calling the hours() function

import Zoo as menagerie  # Import zoo as menagerie

menagerie.hours()  # Call the function
# Out:
# Open 9-5 daily
