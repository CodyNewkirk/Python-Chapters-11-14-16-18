# %%
# Cody Newkirk
# SDEV220
# Testing the zoo.py module by importing and calling its function

import Zoo  # Importing the custom module

Zoo.hours()  # Calling the function to display hours
# Out:
# Open 9-5 daily
